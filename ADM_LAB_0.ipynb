# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit2303A510J0/ADM/blob/main/ADM_LAB_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

def find_file(base_path, file_name):
    for root, dirs, files in os.walk(base_path):
        if file_name in files:
            return os.path.join(root, file_name)
    return None

file_name = input("Enter the text file name: ")

base_path = '/content/drive/MyDrive'

file_path = find_file(base_path, file_name)

if file_path is not None:
  with open(file_path, 'r') as file:
    content = file.read()
    print(content)
else:
  print("File Not Found")
# Out:
# Enter the text file name: linux.txt
# --- gawk '{pattern action}' file
# It reads input line by line splits each line into fields and allows you to apply operations to those fields
#
#
# --- command1 | xargs command2
# It helps run commands that take arguments from other command
#
#    -- -I
# 	This allows you to use {} placeholder for each input
#
#    -- -n
# 	Limits the no. of arguments passed to command2 per execution
#
#    -- -p
#         Prompts the user before executing each command, allowing for confirmation
#
#    -- -d
# 	Specifies a delimiter that separates input items (default is whitespace)
#
#    -- -0
# 	Used with find and xargs -0 to handle filenames with spaces or special characters only
#
#
# --- zbarimg image.png
#     This converts image to text like scan for barcode or qrcode
#
#
# Common Format Specifiers in C:
#
# 1. %d or %i   : Integer (e.g., int)
#    Example: printf("%d", 42);  // Prints: 42
#
# 2. %f         : Floating-point number (e.g., float)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fbbc6650-6ce7-4ff4-88e9-8e508e2878d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbbc6650-6ce7-4ff4-88e9-8e508e2878d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import seaborn as sns
import torch
print(torch.cuda.is_available())
# Out:
# True
